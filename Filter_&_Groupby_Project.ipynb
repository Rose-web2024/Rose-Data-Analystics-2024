# %% [markdown]
# ![Immoscout](https://raw.githubusercontent.com/juliandnl/redi_ss20/master/image.png)

# %% [markdown]
# # Project - Intro to Pandas [Filter and Group]
#
# ---
# ## The description:
# Hi all! You're already familiar with the Immobilienscout 24 dataset from the last project. In this project, we will explore the dataset further by sorting, filtering and grouping.
#
# ---
# ## The dataset:
# The datasets contains information about rental apartments in Berlin.
# One row is for one appartment. The dataset contains 6 columns.
# - Region: is the Berlin district, where the flat is located
# - Condition: is the condition of the flat
# - Rooms: The number of rooms the flat has
# - Rent: Monthly rent for the flat
# - Year_Construction: The year in which the house was build
# - Space: How many square meters does the flat have?
#
# ---
# ## The Task:
# For each question, write code which clearly show the answer to it.

# %%
# Imports
import pandas as pd

# %%
# Read in dataset
rentals = pd.read_csv("https://raw.githubusercontent.com/juliandnl/redi_ss20/master/berlin_rental.csv")
rentals.head()
# Out:
#         Region       Condition  Rooms     Rent  Year_Construction   Space
# 0        Mitte  first_time_use    4.0  2659.00               2019  117.20
# 1    Kreuzberg  first_time_use    1.0  1200.00               2020   29.33
# 2     Köpenick       well_kept    2.0   979.00               1997   83.61
# 3  Wilmersdorf       well_kept    4.0  1830.22               1900  171.18
# 4    Kreuzberg  first_time_use    2.0  2272.00               2020   88.27

# %% [markdown]
# 1.How many apartments in Mitte are in a 'well-kept' condition?

# %%
rentals[(rentals ['Region'] == 'Mitte') & (rentals['Condition'] == 'well-kept')].shape
# Out:
# (0, 6)

# %%
rentals.loc[(rentals['Region'] == 'Mitte') & (rentals['Condition'] == 'well-kept')].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             0 non-null      object
#  1   Condition          0 non-null      object
#  2   Rooms              0 non-null      float64
#  3   Rent               0 non-null      float64
#  4   Year_Construction  0 non-null      int64
#  5   Space              0 non-null      float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 0.0+ bytes

# %%
rentals[rentals['Region'] == 'Mitte']
# Out:
#     Region       Condition  Rooms     Rent  Year_Construction   Space
# 0    Mitte  first_time_use    4.0  2659.00               2019  117.20
# 6    Mitte  mint_condition    2.0  1509.45               2015   61.61
# 10   Mitte  first_time_use    4.0  2499.00               2019  125.20
# 12   Mitte  first_time_use    3.0  2500.00               2019   81.10
# 15   Mitte       well_kept    2.0  1505.60               2018   75.28
# ..     ...             ...    ...      ...                ...     ...
# 736  Mitte       well_kept    3.0  3500.00               2009  165.00
# 741  Mitte  mint_condition    4.0  3925.00               2016  138.00
# 748  Mitte  mint_condition    4.0  4040.00               2015  176.50
# 751  Mitte  no_information    1.5   770.00               1997   35.00
# 754  Mitte  no_information    3.0  2155.50               1879   86.42
#
# [153 rows x 6 columns]

# %%
rentals.query( "Region =='Mitte'& Condition == 'Well-Kept'")
# Out:
# Empty DataFrame
# Columns: [Region, Condition, Rooms, Rent, Year_Construction, Space]
# Index: []

# %% [markdown]
# 2.How many apartments in Kreuzberg were built before 1900?

# %%
rentals.loc[(rentals['Region'] == 'Kreuzberg') & (rentals['Year_Construction'] < 1900)]
# Out:
#         Region                           Condition  Rooms    Rent  \
# 76   Kreuzberg                      first_time_use    5.0  4400.0
# 401  Kreuzberg                         refurbished    4.0  2850.0
# 697  Kreuzberg  first_time_use_after_refurbishment    2.0  1399.0
#
#      Year_Construction  Space
# 76                1867  236.0
# 401               1895  127.0
# 697               1874   50.0

# %% [markdown]
# 3.What are the average apartment sizes by the number of rooms?

# %%
rentals.groupby('Rooms')[['Space']].mean()
# Out:
#             Space
# Rooms
# 1.0     34.470748
# 1.5     41.361111
# 2.0     65.015725
# 2.5     90.463125
# 3.0     99.403167
# 3.5     98.037500
# 4.0    130.863333
# 4.5    106.100000
# 5.0    194.400526
# 6.0    237.000000
# 7.0    251.000000

# %% [markdown]
# 4.Which is the most expensive region on average and what is the maximum rent for this region?

# %%
rentals.groupby('Region')[['Rent']].mean().sort_values(by='Rent', ascending=False)
# Out:
#                         Rent
# Region
# Mitte            2408.725033
# Kreuzberg        2049.138085
# Prenzlauer       1996.962264
# Tiergarten       1914.824795
# Charlottenburg   1753.452532
# Wilmersdorf      1748.646226
# Neukölln         1188.114915
# Köpenick         1125.475818
# Friedrichsfelde  1043.871731
# Wedding           847.138571

# %%
rentals.groupby('Region')[['Rent']].mean().idxmax()
# Out:
# Rent    Mitte
# dtype: object

# %%
rentals.groupby('Region')[['Rent']].mean().max()
# Out:
# Rent    2408.725033
# dtype: float64

# %%
# What is the minimum,maximum and average number of rooms of the apartments in
# Kopenick?

# %%
rentals.groupby('Region')['Rooms'].agg(['min','max','mean'])
# Out:
#                  min  max      mean
# Region
# Charlottenburg   1.0  5.0  2.525316
# Friedrichsfelde  1.0  4.5  2.500000
# Kreuzberg        1.0  5.0  2.489362
# Köpenick         1.0  4.0  2.281818
# Mitte            1.0  5.0  2.754902
# Neukölln         1.0  5.0  2.279661
# Prenzlauer       1.0  6.0  2.660377
# Tiergarten       1.0  5.0  2.736842
# Wedding          1.0  4.0  1.726190
# Wilmersdorf      1.0  7.0  2.613208

# %%
rentals.groupby(rentals['Region']=='Kopenick')[['Rooms']].agg(['min','max','mean'])
# Out:
#        Rooms
#          min  max      mean
# Region
# False    1.0  7.0  2.549738

# %% [markdown]
# ## ** Extra Bonus Question
# 6. Show a table of apartment counts, where rows and columns correspond to year of construction and region, respectively.

# %%
rentals.groupby(['Year_Construction', 'Region']).count()
# Out:
#                                Condition  Rooms  Rent  Space
# Year_Construction Region
# 1864              Mitte                1      1     1      1
# 1867              Kreuzberg            1      1     1      1
# 1870              Köpenick             7      7     7      7
# 1873              Prenzlauer           1      1     1      1
# 1874              Kreuzberg            1      1     1      1
# ...                                  ...    ...   ...    ...
# 2020              Mitte               10     10    10     10
#                   Neukölln             1      1     1      1
#                   Tiergarten           5      5     5      5
#                   Wedding              2      2     2      2
#                   Wilmersdorf          6      6     6      6
#
# [233 rows x 4 columns]

# %% [markdown]
# # ⚠ Optional but important
#
# Colab notebooks are great to show code in class, but you shall be able to run python code on your own machine (it probably has more memory than Colab, which could be usefull during the final projects, for example).
#
# One easy option is to use Jupyter notebook (Colab is actually based on that).
#
#
# <font color='blue'><b> INSTRUCTIONS TO INSTALL JUPYTER NOTEBOOK</b></font>
#
# * Go to the terminal (the command prompt) on your machine and install jupyter notebook with:
# `pip install jupyterlab`
# * Then, still in the terminal, install pandas with:
# `pip install pandas`
# * Finally, still in the terminal, open a jupyter notebook with:
# `jupyter notebook`
# * It may open a browser directly, or give you a URL to paste in a browser, do it.
# * In the page opened in the browser, go to New > Python3 (it's on the right)
# * There you shall be able to run the same code as in a Colab notebok.
#
#
# Try it and let the teachers know if you run into issues.
